# %% [markdown]
# # 2. Text Preprocessing (Demo)
#
# **Goal:** Demonstrate the `clean_text` function from the pipeline.
#
# **Note:** The formal, automated testing for all preprocessing functions now lives in `tests/test_preprocessing.py` and is run with `pytest`.

# %%
import pandas as pd
import sys

sys.path.append('../src')
from preprocessing import clean_text

# %% [markdown]
# ### Test `clean_text`
# This function is used by the pipeline to remove URLs and normalize whitespace.

# %%
dirty_text = "This is GREAT!! <br>Check out this link. http://example.com... It's #awesome."
cleaned = clean_text(dirty_text)
print(f"Original: {dirty_text}")
print(f"Cleaned:  {cleaned}")
# Out:
# Original: This is GREAT!! <br>Check out this link. http://example.com... It's #awesome.
# Cleaned:  This is GREAT!! <br>Check out this link. It's #awesome.
